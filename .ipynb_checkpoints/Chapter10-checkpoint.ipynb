# %% [markdown]
# # Upgrading our MNIST Network

# %%
import numpy as np, sys
np.random.seed(1)

from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000,28*28) / 255, y_train[0:1000])

one_hot_labels = np.zeros((len(labels),10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

alpha, iterations = (2, 300)
pixels_per_image, num_labels = (784, 10)
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 8

hidden_size = ((input_rows - kernel_rows) * (input_cols - kernel_cols)) * num_kernels

# weights_0_1 = 0.02*np.random.random((pixels_per_image,hidden_size))-0.01
kernels = 0.02*np.random.random((kernel_rows*kernel_cols,num_kernels))-0.01
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1


def get_image_section(layer,row_from, row_to, col_from, col_to):
    return layer[:,row_from:row_to,col_from:col_to].reshape(-1,1,row_to-row_from, col_to-col_from)

for j in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end=((i * batch_size),((i+1)*batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0, row_start,row_start+kernel_rows, col_start,col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        dropout_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1,weights_1_2))

        for k in range(batch_size):
            correct_cnt += int(np.argmax(layer_2[k:k+1]) == np.argmax(labels[batch_start+k:batch_start+k+1]))

        layer_2_delta = (labels[batch_start:batch_end]-layer_2) / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        kernels -= alpha * flattened_input.T.dot(layer_1_delta.reshape(kernel_output.shape))
    
    test_correct_cnt = 0

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
#         layer_1 = tanh(np.dot(layer_0,weights_0_1))
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0, row_start,row_start+kernel_rows, col_start,col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        layer_2 = np.dot(layer_1,weights_1_2)

        test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
    if(j % 1 == 0):
        sys.stdout.write("\n"+ \
         "I:" + str(j) + \
         " Test-Acc:"+str(test_correct_cnt/float(len(test_images)))+\
         " Train-Acc:" + str(correct_cnt/float(len(images))))
# Out:
# I:0 Test-Acc:0.0636 Train-Acc:0.059
# I:1 Test-Acc:0.0656 Train-Acc:0.049
# I:2 Test-Acc:0.0675 Train-Acc:0.049
# I:3 Test-Acc:0.0728 Train-Acc:0.068
# I:4 Test-Acc:0.0769 Train-Acc:0.071
# I:5 Test-Acc:0.0909 Train-Acc:0.077
# I:6 Test-Acc:0.125 Train-Acc:0.072
# I:7 Test-Acc:0.1753 Train-Acc:0.123
# I:8 Test-Acc:0.2267 Train-Acc:0.126
# I:9 Test-Acc:0.2684 Train-Acc:0.142
# I:10 Test-Acc:0.3104 Train-Acc:0.154
# I:11 Test-Acc:0.3373 Train-Acc:0.192
# I:12 Test-Acc:0.3575 Train-Acc:0.189
# I:13 Test-Acc:0.361 Train-Acc:0.213
# I:14 Test-Acc:0.3152 Train-Acc:0.202
# I:15 Test-Acc:0.1806 Train-Acc:0.178
# I:16 Test-Acc:0.0789 Train-Acc:0.115
# I:17 Test-Acc:0.0429 Train-Acc:0.054
# I:18 Test-Acc:0.0313 Train-Acc:0.041
# I:19 Test-Acc:0.03 Train-Acc:0.037
# I:20 Test-Acc:0.0389 Train-Acc:0.044
# I:21 Test-Acc:0.0579 Train-Acc:0.058
# I:22 Test-Acc:0.0923 Train-Acc:0.084
# I:23 Test-Acc:0.1604 Train-Acc:0.09
# I:24 Test-Acc:0.2365 Train-Acc:0.139
# I:25 Test-Acc:0.3373 Train-Acc:0.188
# I:26 Test-Acc:0.4131 Train-Acc:0.205
# I:27 Test-Acc:0.4752 Train-Acc:0.262
# I:28 Test-Acc:0.5117 Train-Acc:0.3
# I:29 Test-Acc:0.5346 Train-Acc:0.333
# I:30 Test-Acc:0.533 Train-Acc:0.343
# I:31 Test-Acc:0.5093 Train-Acc:0.329
# I:32 Test-Acc:0.4504 Train-Acc:0.309
# I:33 Test-Acc:0.3079 Train-Acc:0.233
# I:34 Test-Acc:0.1614 Train-Acc:0.167
# I:35 Test-Acc:0.08 Train-Acc:0.101
# I:36 Test-Acc:0.0464 Train-Acc:0.072
# I:37 Test-Acc:0.0352 Train-Acc:0.042
# I:38 Test-Acc:0.029 Train-Acc:0.034
# I:39 Test-Acc:0.0271 Train-Acc:0.039
# I:40 Test-Acc:0.0218 Train-Acc:0.039
# I:41 Test-Acc:0.0262 Train-Acc:0.041
# I:42 Test-Acc:0.0729 Train-Acc:0.052
# I:43 Test-Acc:0.1854 Train-Acc:0.085
# I:44 Test-Acc:0.3183 Train-Acc:0.097
# I:45 Test-Acc:0.4159 Train-Acc:0.186
# I:46 Test-Acc:0.4765 Train-Acc:0.23
# I:47 Test-Acc:0.5204 Train-Acc:0.228
# I:48 Test-Acc:0.5523 Train-Acc:0.309
# I:49 Test-Acc:0.5845 Train-Acc:0.315
# I:50 Test-Acc:0.6051 Train-Acc:0.329
# I:51 Test-Acc:0.6156 Train-Acc:0.353
# I:52 Test-Acc:0.618 Train-Acc:0.339
# I:53 Test-Acc:0.6172 Train-Acc:0.356
# I:54 Test-Acc:0.6262 Train-Acc:0.351
# I:55 Test-Acc:0.6462 Train-Acc:0.379
# I:56 Test-Acc:0.6666 Train-Acc:0.423
# I:57 Test-Acc:0.6847 Train-Acc:0.413
# I:58 Test-Acc:0.6981 Train-Acc:0.412
# I:59 Test-Acc:0.7054 Train-Acc:0.437
# I:60 Test-Acc:0.7161 Train-Acc:0.454
# I:61 Test-Acc:0.7266 Train-Acc:0.467
# I:62 Test-Acc:0.7341 Train-Acc:0.472
# I:63 Test-Acc:0.7394 Train-Acc:0.476
# I:64 Test-Acc:0.7481 Train-Acc:0.477
# I:65 Test-Acc:0.7478 Train-Acc:0.483
# I:66 Test-Acc:0.755 Train-Acc:0.506
# I:67 Test-Acc:0.7583 Train-Acc:0.508
# I:68 Test-Acc:0.7692 Train-Acc:0.514
# I:69 Test-Acc:0.7709 Train-Acc:0.513
# I:70 Test-Acc:0.7741 Train-Acc:0.541
# I:71 Test-Acc:0.7811 Train-Acc:0.543
# I:72 Test-Acc:0.7857 Train-Acc:0.538
# I:73 Test-Acc:0.7894 Train-Acc:0.571
# I:74 Test-Acc:0.794 Train-Acc:0.57
# I:75 Test-Acc:0.7966 Train-Acc:0.6
# I:76 Test-Acc:0.7959 Train-Acc:0.595
# I:77 Test-Acc:0.8012 Train-Acc:0.592
# I:78 Test-Acc:0.8059 Train-Acc:0.607
# I:79 Test-Acc:0.808 Train-Acc:0.64
# I:80 Test-Acc:0.8074 Train-Acc:0.622
# I:81 Test-Acc:0.8124 Train-Acc:0.609
# I:82 Test-Acc:0.8133 Train-Acc:0.644
# I:83 Test-Acc:0.8168 Train-Acc:0.648
# I:84 Test-Acc:0.8201 Train-Acc:0.665
# I:85 Test-Acc:0.8208 Train-Acc:0.649
# I:86 Test-Acc:0.823 Train-Acc:0.649
# I:87 Test-Acc:0.8235 Train-Acc:0.669
# I:88 Test-Acc:0.8241 Train-Acc:0.675
# I:89 Test-Acc:0.8258 Train-Acc:0.68
# I:90 Test-Acc:0.8271 Train-Acc:0.683
# I:91 Test-Acc:0.8298 Train-Acc:0.692
# I:92 Test-Acc:0.8308 Train-Acc:0.676
# I:93 Test-Acc:0.8331 Train-Acc:0.685
# I:94 Test-Acc:0.8305 Train-Acc:0.687
# I:95 Test-Acc:0.8344 Train-Acc:0.693
# I:96 Test-Acc:0.8328 Train-Acc:0.697
# I:97 Test-Acc:0.835 Train-Acc:0.684
# I:98 Test-Acc:0.8378 Train-Acc:0.7
# I:99 Test-Acc:0.8391 Train-Acc:0.705
# I:100 Test-Acc:0.8378 Train-Acc:0.707
# I:101 Test-Acc:0.8424 Train-Acc:0.702
# I:102 Test-Acc:0.8414 Train-Acc:0.715
# I:103 Test-Acc:0.8421 Train-Acc:0.724
# I:104 Test-Acc:0.8434 Train-Acc:0.717
# I:105 Test-Acc:0.8453 Train-Acc:0.72
# I:106 Test-Acc:0.8451 Train-Acc:0.723
# I:107 Test-Acc:0.8438 Train-Acc:0.728
# I:108 Test-Acc:0.846 Train-Acc:0.717
# I:109 Test-Acc:0.8458 Train-Acc:0.739
# I:110 Test-Acc:0.8478 Train-Acc:0.72
# I:111 Test-Acc:0.8476 Train-Acc:0.717
# I:112 Test-Acc:0.8483 Train-Acc:0.739
# I:113 Test-Acc:0.8462 Train-Acc:0.725
# I:114 Test-Acc:0.8507 Train-Acc:0.733
# I:115 Test-Acc:0.8529 Train-Acc:0.73
# I:116 Test-Acc:0.8527 Train-Acc:0.736
# I:117 Test-Acc:0.8504 Train-Acc:0.728
# I:118 Test-Acc:0.852 Train-Acc:0.728
# I:119 Test-Acc:0.8512 Train-Acc:0.734
# I:120 Test-Acc:0.854 Train-Acc:0.738
# I:121 Test-Acc:0.8542 Train-Acc:0.737
# I:122 Test-Acc:0.8565 Train-Acc:0.731
# I:123 Test-Acc:0.8572 Train-Acc:0.738
# I:124 Test-Acc:0.856 Train-Acc:0.747
# I:125 Test-Acc:0.8551 Train-Acc:0.755
# I:126 Test-Acc:0.8567 Train-Acc:0.761
# I:127 Test-Acc:0.8592 Train-Acc:0.746
# I:128 Test-Acc:0.8568 Train-Acc:0.743
# I:129 Test-Acc:0.8581 Train-Acc:0.763
# I:130 Test-Acc:0.8611 Train-Acc:0.751
# I:131 Test-Acc:0.8616 Train-Acc:0.772
# I:132 Test-Acc:0.8639 Train-Acc:0.75
# I:133 Test-Acc:0.862 Train-Acc:0.749
# I:134 Test-Acc:0.8615 Train-Acc:0.758
# I:135 Test-Acc:0.8633 Train-Acc:0.755
# I:136 Test-Acc:0.861 Train-Acc:0.759
# I:137 Test-Acc:0.8638 Train-Acc:0.768
# I:138 Test-Acc:0.8618 Train-Acc:0.764
# I:139 Test-Acc:0.8588 Train-Acc:0.744
# I:140 Test-Acc:0.8634 Train-Acc:0.76
# I:141 Test-Acc:0.8611 Train-Acc:0.74
# I:142 Test-Acc:0.8624 Train-Acc:0.744
# I:143 Test-Acc:0.8641 Train-Acc:0.763
# I:144 Test-Acc:0.8625 Train-Acc:0.762
# I:145 Test-Acc:0.8614 Train-Acc:0.754
# I:146 Test-Acc:0.8613 Train-Acc:0.767
# I:147 Test-Acc:0.8643 Train-Acc:0.767
# I:148 Test-Acc:0.8639 Train-Acc:0.759
# I:149 Test-Acc:0.864 Train-Acc:0.76
# I:150 Test-Acc:0.8631 Train-Acc:0.765
# I:151 Test-Acc:0.8632 Train-Acc:0.776
# I:152 Test-Acc:0.8647 Train-Acc:0.778
# I:153 Test-Acc:0.8665 Train-Acc:0.766
# I:154 Test-Acc:0.8656 Train-Acc:0.772
# I:155 Test-Acc:0.8672 Train-Acc:0.78
# I:156 Test-Acc:0.8676 Train-Acc:0.763
# I:157 Test-Acc:0.8668 Train-Acc:0.778
# I:158 Test-Acc:0.8691 Train-Acc:0.773
# I:159 Test-Acc:0.8699 Train-Acc:0.784
